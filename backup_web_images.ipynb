# %%
web_image_dir_path='/home/carnd/GermanTrafficSigns/'

from os import walk
import matplotlib.image as mpimg

file = open("/home/carnd/CarND-Traffic-Sign-Classifier-Project/data.pkl", "wb")
f = []
address=''

for (dirpath, dirnames, filenames) in walk(web_image_dir_path):
    f.extend(filenames)
    break

for i in f:
    address=web_image_dir_path+''.join(i)
    pickle.dump(address, file)
    address=''
file.close()

file = open("/home/carnd/CarND-Traffic-Sign-Classifier-Project/data.pkl", "rb")
image1 = pickle.load(file)
file.close()


image = mpimg.imread("/home/carnd/GermanTrafficSigns/459381007.jpg")
plt.imshow(image)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread("/home/carnd/CarND-Traffic-Sign-Classifier-Project/GermanTrafficSigns/1.png")
plt.imshow(image)
plt.show()
print(image.shape)
# Out:
# (240, 240, 4)

# %%
import PIL
from PIL import Image

#basewidth = 300
#img = Image.open('somepic.jpg')
#wpercent = (basewidth/float(img.size[0]))
#hsize = int((float(img.size[1])*float(wpercent)))
#img = img.resize((basewidth,hsize), PIL.Image.ANTIALIAS)
#img.save('sompic.jpg') 
im = Image.open("/home/carnd/CarND-Traffic-Sign-Classifier-Project/GermanTrafficSigns/1.png")
img=im.resize((32,32),PIL.Image.ANTIALIAS)
plt.imshow(img)
plt.show()
img.save("/home/carnd/CarND-Traffic-Sign-Classifier-Project/GermanTrafficSigns/1_1.jpg", "JPEG")
print(img.size)
# Out:
# (32, 32)

# %%
image = mpimg.imread("/home/carnd/CarND-Traffic-Sign-Classifier-Project/GermanTrafficSigns/1_1.jpg")
plt.imshow(image)
plt.show()
print(image.shape)
# Out:
# (32, 32, 3)

# %%
import os
filelist= [file for file in os.listdir('/home/carnd/CarND-Traffic-Sign-Classifier-Project/GermanTrafficSigns/') if file.endswith('.png')]

# %%
print(filelist)
# Out:
# ['2.png', '1_1.png', '3.png', '4.png', '1.png', '5.png']
